# %% [markdown]
# # GTHA housing market database
# # OSEMN methodology Step 1: Obtain
# # Obtain Select DA-level Census Variables
#
# ---
#
# This notebook describes _Step 1: Obtain_ of OSEMN methodology, the process of select DA-level Census variables.
#
# ---
#
# For description of OSEMN methodology, see `methodology/0.osemn/osemn.pdf`.
#
# ## Import dependencies

# %%
import pandas as pd
import os
from time import time

# %%
data_path = '../../../data/census/taz_level_vars/'
os.listdir(data_path)
# Out:
# ['taz_census_age_edu_employment.xlsx', 'taz_census_housing_monetaryvars.xlsx']

# %% [markdown]
# ## Load geometry of GTHA Dissemination Areas (DAs)

# %%
t = time()
df = pd.read_excel(data_path + 'taz_census_age_edu_employment.xlsx.xls')
elapsed = time() - t
print("\n----- DataFrame loaded"
      "\nin {0:.2f} seconds".format(elapsed) + 
      "\nwith {0:,} rows\nand {1:,} columns"
      .format(df.shape[0], df.shape[1]) + 
      "\n-- Column names:\n", df.columns)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-66e2772e8bc6> in <module>
#       1 t = time()
# ----> 2 df = pd.read_excel(data_path + 'taz_census_age_edu_employment.xlsx.xls')
#       3 elapsed = time() - t
#       4 print("\n----- DataFrame loaded"
#       5       "\nin {0:.2f} seconds".format(elapsed) +
#
# ~/anaconda3/envs/twitter/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/anaconda3/envs/twitter/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# ~/anaconda3/envs/twitter/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# ~/anaconda3/envs/twitter/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      18         """
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
# ---> 20         import_optional_dependency("xlrd", extra=err_msg)
#      21         super().__init__(filepath_or_buffer)
#      22
#
# ~/anaconda3/envs/twitter/lib/python3.7/site-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#      91     except ImportError:
#      92         if raise_on_missing:
# ---> 93             raise ImportError(message.format(name=name, extra=extra)) from None
#      94         else:
#      95             return None
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.

# %% [markdown]
# ## Convert data to tidy format
# Same variables are stored in several columns corresponding to different Census years, which violates one of the conditions of Tidy Data. To correct this, a new column `year` will be added to be used as a part of a **_primary key_** along with `dauid` for the `da_census_select` table in the database. DataFrame will be melted for each variable to be stored in a single column additionally referenced by the column `year`.

# %% [markdown]
# ### Desired shape of the DataFrame
# There are 30 unique variables for each Census year, 31 unique variables in total (variable `Self-emp` gets renamed to `Self_emp` in 2016 Census, to be corrected after melting).

# %%
mask1 = df.columns.str.contains('01')
cols = df.columns[mask1]
len(cols)
# Out:
# 30

# %% [markdown]
# #### All Census variables in the original table

# %%
var_names = df.columns[df.columns.str.contains('\d')]
var_names = var_names.str.slice(stop=-2)
var_names = var_names.unique()
len(var_names)
# Out:
# 31

# %%
var_names
# Out:
# Index(['Avg_HHsize', 'Avg_HHinc', 'Avg_own_payt', 'Avg_val_dwel', 'Avg_rent',
#        'Pop', 'PopDens', 'Dwel', 'DwelDens', 'Sgl_det', 'Apt_5plus', 'Sgl_att',
#        'Owned', 'Rented', 'CarTrVan_d', 'CarTrVan_p', 'PT', 'Walk', 'Bike',
#        'Lbrfrc', 'Emp', 'Unemp', 'Not_lbrfrc', 'Employee', 'Self_emp',
#        'At_home', 'No_fix_wkpl', 'Usl_wkpl', 'Blue_cljob', 'White_cljob',
#        'Self-emp'],
#       dtype='object')

# %% [markdown]
# There are four different Census years:

# %%
mask1 = df.columns.str.contains('Avg_HHsize')
cols = df.columns[mask1]
cols
# Out:
# Index(['Avg_HHsize16', 'Avg_HHsize11', 'Avg_HHsize06', 'Avg_HHsize01'], dtype='object')

# %% [markdown]
# There are 9'182 Dissemination Areas.

# %%
df.index.nunique()
# Out:
# 9182

# %%
len(df)
# Out:
# 9182

# %%
len(df) * 4
# Out:
# 36728

# %% [markdown]
# That means, that after melting we should get a table with 9'182 x 4 = 36'728 rows and 32 columns (`DAUID`, `year`, and 31 columns with Census variables).

# %% [markdown]
# ### Melt all the variables in the table

# %%
i = 0

for var_name in var_names:

    # select a subset of columns containing different years of a Census variable
    mask1 = df.columns.str.contains('{0}\d'.format(var_name))
    var_cols = df.columns[mask1]
    s = df[['DAUID'] + list(var_cols)]

    df_melt = pd.melt(s, id_vars='DAUID', value_name=var_name)
    df_melt['variable'] = '20' + df_melt['variable'].str.slice(-2)
    df_melt = df_melt.rename(columns={'variable': 'year'})
    df_melt['year'] = df_melt['year'].astype('int')
    if i  == 0:
        df_tidy = df_melt.sort_values('DAUID')
    else:
        df_tidy = pd.merge(df_tidy, df_melt, how='left', 
                           left_on=['DAUID', 'year'], right_on=['DAUID', 'year'])
    i += 1

df_tidy.sort_values(['DAUID', 'year'])
# Out:
#           DAUID  year  Avg_HHsize      Avg_HHinc  Avg_own_payt   Avg_val_dwel  \
# 3      35180017  2001    2.945455   82963.090909   1079.181818  248639.000000
# 2      35180017  2006    2.958333  105432.416667   1336.583333  397211.500000
# 1      35180017  2011    2.841667  124624.250000   1565.750000  537326.583333
# 0      35180017  2016    2.900000  137158.000000   1764.000000  673145.000000
# 6      35180018  2001    2.837500   72401.875000   1101.625000  230609.500000
# ...         ...   ...         ...            ...           ...            ...
# 36723  35251038  2016    3.500000  137275.000000   2196.000000  626247.000000
# 36727  35251039  2001    3.200000   83715.250000    973.000000  224460.250000
# 36726  35251039  2006    3.150000  100682.000000   1352.250000  369772.000000
# 36724  35251039  2011    3.200000  125604.000000   1776.000000  446128.000000
# 36725  35251039  2016    3.500000  161570.000000   2206.000000  698845.000000
#
#           Avg_rent   Pop      PopDens   Dwel  ...  Unemp  Not_lbrfrc  \
# 3       492.363636   883    14.267301  284.0  ...   10.0       152.0
# 2       672.250000   843    13.620991  281.0  ...    0.0       168.0
# 1       336.250000   871    14.073408  292.0  ...    1.0       154.0
# 0      1224.000000   845    13.653306  290.0  ...   20.0       170.0
# 6       654.875000   681   111.155307  241.0  ...   25.0       103.0
# ...            ...   ...          ...    ...  ...    ...         ...
# 36723  1721.000000  1976  2601.081412  560.0  ...   60.0       295.0
# 36727   444.250000   402   276.383033  133.0  ...   21.0       100.0
# 36726   364.500000   645   443.450389  219.0  ...   14.0       125.0
# 36724  1427.000000  1436   987.278695  451.0  ...   34.0       348.0
# 36725     0.000000  1617  1111.719812  455.0  ...   60.0       390.0
#
#        Employee  Self_emp  At_home  No_fix_wkpl  Usl_wkpl  Blue_cljob  \
# 3         390.0       NaN    155.0         30.0     335.0       236.0
# 2         422.0       NaN    105.0         67.0     377.0       172.0
# 1         435.0       NaN     56.0         76.0     380.0       258.0
# 0         440.0     130.0    100.0         80.0     380.0       225.0
# 6         330.0       NaN     39.0         20.0     310.0       103.0
# ...         ...       ...      ...          ...       ...         ...
# 36723     915.0     205.0    100.0        135.0     815.0       260.0
# 36727     165.0       NaN      6.0         16.0     159.0        43.0
# 36726     302.0       NaN     16.0         36.0     291.0        97.0
# 36724     609.0       NaN     54.0         71.0     583.0       210.0
# 36725     625.0     170.0     55.0         55.0     630.0       160.0
#
#        White_cljob  Self-emp
# 3            295.0     141.0
# 2            357.0     121.0
# 1            260.0     121.0
# 0            350.0       NaN
# 6            310.0      74.0
# ...            ...       ...
# 36723        870.0       NaN
# 36727        154.0      26.0
# 36726        258.0      50.0
# 36724        508.0     128.0
# 36725        630.0       NaN
#
# [36728 rows x 33 columns]

# %% [markdown]
# #### Assign values of `Self_emp` to `Self-emp`

# %%
mask1 = df_tidy['year'] == 2016
df_tidy.loc[mask1, 'Self_emp'].isnull().sum()
# Out:
# 35

# %%
df_tidy.loc[~mask1, 'Self_emp'].isnull().sum()
# Out:
# 27546

# %%
df_tidy.loc[~mask1, 'Self_emp'] = df_tidy.loc[~mask1, 'Self-emp']
df_tidy.loc[~mask1, 'Self_emp'].isnull().sum()
# Out:
# 30

# %% [markdown]
# #### Drop column `Self-emp`

# %%
df_tidy = df_tidy.drop('Self-emp', axis=1)
df_tidy.columns
# Out:
# Index(['DAUID', 'year', 'Avg_HHsize', 'Avg_HHinc', 'Avg_own_payt',
#        'Avg_val_dwel', 'Avg_rent', 'Pop', 'PopDens', 'Dwel', 'DwelDens',
#        'Sgl_det', 'Apt_5plus', 'Sgl_att', 'Owned', 'Rented', 'CarTrVan_d',
#        'CarTrVan_p', 'PT', 'Walk', 'Bike', 'Lbrfrc', 'Emp', 'Unemp',
#        'Not_lbrfrc', 'Employee', 'Self_emp', 'At_home', 'No_fix_wkpl',
#        'Usl_wkpl', 'Blue_cljob', 'White_cljob'],
#       dtype='object')

# %% [markdown]
# #### Validate the shape of the melted DataFrame

# %%
df.shape
# Out:
# (9182, 124)

# %%
df_tidy.shape
# Out:
# (36728, 32)

# %% [markdown]
# ## Save results to a .csv file

# %%
save_path = data_path + 'da_census_select_tidy.csv'
t = time()
df_tidy.sort_values(['DAUID', 'year']).to_csv(save_path, index=False)
elapsed = time() - t
print("DataFrame saved to file:\n", save_path,
      "\ntook {0:.2f} seconds".format(elapsed))
# Out:
# DataFrame saved to file:
#  ../../../data/da_census/da_census_select_tidy.csv
# took 1.81 seconds
